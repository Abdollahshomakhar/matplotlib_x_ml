# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from plt_one_addpt_onclick import plt_one_addpt_oncliick
from plt_one_addpt_oneclick2 import plt_one_addpt_onclick
from lab_utils_common import draw_vthresh
from plt_one_addpt_onclick_kmeans import plt_one_addpt_onclick_kmeans
plt.style.use('./deeplearning.mplstyle')

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])

w_in = np.zeros((1))
b_in = 0

# %%
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=True)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
addpt = plt_one_addpt_oncliick( x_train,y_train, w_in, b_in, logistic=False)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# E:\kaggle\باربد\New folder

# %%
# داده‌های اولیه (نزدیک‌تر به یکدیگر)
X = np.array([
    [1.5, 2.0], 
    [1.8, 2.1], 
    [2.0, 2.2], 
    [2.3, 2.0], 
    [2.5, 2.1]
])
initial_centroids = np.array([
    [1.6, 2.0], 
    [2.4, 2.1]
])

# %%
# نمونه استفاده
kmeans_plot = plt_one_addpt_onclick_kmeans(X, initial_centroids, max_iters=10)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
